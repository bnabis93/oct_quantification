# %%
import cv2
import numpy as np
import os
import sys

sys.path.insert(0, './lib_keras/')

from help_functions import *

# width = 16 / hight = 51

# %%
sample_data = cv2.imread('./data/fine_segmentor_data/fine_train/000.png')
sample_data = sample_data[:,:,1]

sample_mask = np.zeros((np.shape(sample_data)))

show_on_jupyter(sample_data,'gray')

row,col = np.where(sample_data > 250)
sample_mask[row,col] = 255

cv2.imwrite('./mask.png',sample_mask)
cv2.imwrite('./sample_img.png', sample_data)
# Out:
# True

# %%
show_on_jupyter(sample_mask,'gray')
